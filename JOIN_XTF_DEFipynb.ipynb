# %% [markdown]
# <a href="https://colab.research.google.com/github/IgnasiOliveras/anonimitzar/blob/main/JOIN_XTF_DEFipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_principal = pd.read_excel('/content/30.01.25 Uic.xlsx', sheet_name='Export')
# subset_df = df_principal[df_principal['OpenchannelInteractionId'] == 1489]

# Cargar la hoja "Export" del archivo 30.01.25_Uic.xlsx
# df_principal = subset_df

# Cargar el archivo de tipificaciones (CSV)
df_tipificaciones = pd.read_excel('/content/20.02.25TipificacionesConversaciones.xlsx')
df_tipificaciones = df_tipificaciones.rename(columns={'ContactId': 'ContactId1'})

# 2️⃣ Cargar el archivo de Fichas CRM (suponiendo que es Excel)
df_fichas_crm = pd.read_excel('/content/20.02.25FichasCrm (2).xlsx')
df_fichas_crm = df_fichas_crm.rename(columns={'ContactId': 'ContactId2'})

# Realizar el LEFT JOIN
df_merged = pd.merge(
    df_principal,
    df_tipificaciones,
    how='left',
    left_on=['OpenchannelInteractionId', 'ContactId'],
    right_on=['id', 'ContactId1']
)

# Verificar el resultado
print(df_merged.head())

# Guardar el resultado en un nuevo archivo CSV (opcional)
df_merged.to_csv('resultado_left_join.csv', index=False)

# Convert 'createdAt' to datetime if it's not already
df_principal['createdAt'] = pd.to_datetime(df_principal['createdAt']) # Remove format to allow pandas to infer

# Format 'createdAt' to include only day, month, and year
df_principal['createdAt'] = df_principal['createdAt'].dt.strftime('%d-%m-%Y')

# Format 'Data/hora inici' to include only day, month, and year
# CORRECTED LINE: Remove format to allow pandas to infer the correct format
df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'])
df_fichas_crm['Data/hora inici'] = df_fichas_crm['Data/hora inici'].dt.strftime('%d-%m-%Y')

# Ensure df_merged1['createdAt'] also has the correct format before the final merge
# Apply the same formatting to df_merged1['createdAt'] and specify format
# using errors='coerce' to handle potential errors during conversion to datetime
# CHANGED LINE: Rename 'ContactId' to 'ContactId1' to match with df_fichas_crm
df_merged['createdAt'] = pd.to_datetime(df_merged['createdAt'], format='%d-%m-%Y', errors='coerce').dt.strftime('%d-%m-%Y')
df_merged1 = df_merged

# Realizar el LEFT JOIN sin renombrar ni crear columnas
df_merged_final = pd.merge(
    df_merged1,
    df_fichas_crm,
    how='left',
    left_on= ['ContactId1','createdAt'], # Use ContactId1 to match df_tipificaciones's ContactId1
    right_on=['ContactId2','Data/hora inici']
)


# Verificar el resultado
print(df_merged_final.head())

# Guardar el resultado en un nuevo archivo Excel
df_merged_final.to_excel('resultado_ficha_def.xlsx', index=False)
# Out:
#     id_x                                               body  read  secret  \
# 0  77623                                               Hola     1       0
# 1  77624  Benvingut/da a *Xat de suport emocional per a ...     1       0
# 2  77625                                   Me llamo sakhina     1       0
# 3  77626                                              Hola!     1       0
# 4  77627  Antes de empezar a chatear, es necesario que l...     1       0
#
#   direction              readAt  providerName  providerResponse  \
# 0        in 2023-01-01 00:11:06           NaN               NaN
# 1       out                 NaT           NaN               NaN
# 2        in 2023-01-01 00:11:07           NaN               NaN
# 3       out                 NaT           NaN               NaN
# 4       out                 NaT           NaN               NaN
#
#             createdAt           updatedAt  ...  AttachmentId  integrationId  \
# 0 2023-01-01 00:10:19 2023-01-01 00:11:06  ...           NaN            NaN
# 1 2023-01-01 00:10:19 2023-01-01 00:10:19  ...           NaN            NaN
# 2 2023-01-01 00:10:37 2023-01-01 00:11:07  ...           NaN            NaN
# 3 2023-01-01 00:11:12 2023-01-01 00:11:12  ...           NaN            NaN
# 4 2023-01-01 00:11:33 2023-01-01 00:11:33  ...           NaN            NaN
#
#    parentIntegrationId  sentBy  id_y  closed            closedAt  \
# 0                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 1                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 2                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 3                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 4                  NaN     NaN  1489       1 2023-01-01 00:35:18
#
#       disposition  note  ContactId1
# 0  Conversa atesa   NaN         466
# 1  Conversa atesa   NaN         466
# 2  Conversa atesa   NaN         466
# 3  Conversa atesa   NaN         466
# 4  Conversa atesa   NaN         466
#
# [5 rows x 24 columns]
#     id_x                                               body  read  secret  \
# 0  77623                                               Hola     1       0
# 1  77624  Benvingut/da a *Xat de suport emocional per a ...     1       0
# 2  77625                                   Me llamo sakhina     1       0
# 3  77626                                              Hola!     1       0
# 4  77627  Antes de empezar a chatear, es necesario que l...     1       0
#
#   direction              readAt  providerName  providerResponse   createdAt  \
# 0        in 2023-01-01 00:11:06           NaN               NaN  01-01-2023
# 1       out                 NaT           NaN               NaN  01-01-2023
# 2        in 2023-01-01 00:11:07           NaN               NaN  01-01-2023
# 3       out                 NaT           NaN               NaN  01-01-2023
# 4       out                 NaT           NaN               NaN  01-01-2023
#
#             updatedAt  ...  Vinculació: No  \
# 0 2023-01-01 00:11:06  ...              No
# 1 2023-01-01 00:10:19  ...              No
# 2 2023-01-01 00:11:07  ...              No
# 3 2023-01-01 00:11:12  ...              No
# 4 2023-01-01 00:11:33  ...              No
#
#    Vinculació: No s’ha pogut conèixer aquesta informació  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    Vinculació: S’ha ofert informació d’algun recurs  \
# 0                                                No
# 1                                                No
# 2                                                No
# 3                                                No
# 4                                                No
#
#    Vinculació: Si la resposta és “Sí”: Digues quin        QUÈ S’HA ACONSEGUIT  \
# 0                                              NaN  Companyia / socialització
# 1                                              NaN  Companyia / socialització
# 2                                              NaN  Companyia / socialització
# 3                                              NaN  Companyia / socialització
# 4                                              NaN  Companyia / socialització
#
#    QUÈ S’HA ACONSEGUIT. Altres  Activació serveis emergències: 061  \
# 0                          NaN                                  No
# 1                          NaN                                  No
# 2                          NaN                                  No
# 3                          NaN                                  No
# 4                          NaN                                  No
#
#    Activació serveis emergències: 112 / 116 (Emergències Andorra)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    Activació serveis emergències: 116111 (Infància respon)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    Mantenim el contacte pel xat fins que arriben els serveis d’emergència
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
# [5 rows x 71 columns]

# %%
import pandas as pd

df_principal = pd.read_excel('/content/30.01.25 Uic.xlsx', sheet_name='Export')

# Crear DataFrame de ejemplo
#data = df_principal["createdAt"]
df = df_principal
import pandas as pd

# Convertir a datetime and assign to a new column in the DataFrame.
df["fecha"] = pd.to_datetime(df["createdAt"], format="%d/%m/%Y").dt.date

# Calcular inicio y fin del intervalo de 10 segundos
start_time = df["createdAt"].dt.floor('10S')
end_time = start_time + pd.Timedelta(seconds=10)

# Crear la variable de rango
df["rango"] = (
    start_time.dt.strftime("%H:%M:%S")
    + "-"
    + end_time.dt.strftime("%H:%M:%S")
)


print(df.head(20))
start_time = df["createdAt"].dt.floor('10S')
end_time = start_time + pd.Timedelta(seconds=10)

# Crear la variable de rango
df["rango_hora_10"] = (
    start_time.dt.strftime("%H:%M:%S")
    + "-"
    + end_time.dt.strftime("%H:%M:%S")
)

print(df.head(20))

# Cargar el archivo
df_fichas_crm = pd.read_excel('/content/20.02.25FichasCrm (2).xlsx')

# Convertir a datetime, permitiendo inferencia de formato
df_fichas_crm["fecha"] = pd.to_datetime(df_fichas_crm["Data/hora inici"], errors="coerce", dayfirst=True)

# Verificar si hay valores NaT (fechas no convertidas correctamente)
print("Valores NaT en fecha:")
print(df_fichas_crm[df_fichas_crm["fecha"].isna()][["Data/hora inici", "fecha"]])

# Crear una versión de la fecha en formato string (para mostrar, no para cálculos)
df_fichas_crm["fecha_str"] = df_fichas_crm["fecha"].dt.strftime("%d/%m/%Y")
df_fichas_crm = df_fichas_crm.rename(columns={'Número de telèfon de l’usuari': 'ContactId2'})

# Calcular inicio y fin del intervalo de 10 segundos (usando fecha en datetime)
start_time = df_fichas_crm["fecha"].dt.floor('10S')
end_time = start_time + pd.Timedelta(seconds=10)

# Crear la variable de rango
df_fichas_crm["rango2"] = (
    start_time.dt.strftime("%H:%M:%S")
    + "-"
    + end_time.dt.strftime("%H:%M:%S")
)

# Mostrar datos
print(df_fichas_crm.head(20))


# Cargar el archivo de tipificaciones (CSV)
df_tipificaciones = pd.read_excel('/content/20.02.25TipificacionesConversaciones.xlsx')
df_tipificaciones = df_tipificaciones.rename(columns={'ContactId': 'ContactId1'})


# Realizar el LEFT JOIN
df_merged = pd.merge(
    df_principal,
    df_tipificaciones,
    how='left',
    left_on=['OpenchannelInteractionId', 'ContactId'],
    right_on=['id', 'ContactId1']
)

# Verificar el resultado
print(df_merged.head())

# Guardar el resultado en un nuevo archivo CSV (opcional)
df_merged.to_csv('resultado_left_join.csv', index=False)

# Convert 'createdAt' to datetime if it's not already
#df_principal['createdAt'] = pd.to_datetime(df_principal['createdAt']) # Remove format to allow pandas to infer

# Format 'createdAt' to include only day, month, and year
#df_principal['createdAt'] = df_principal['createdAt'].dt.strftime('%d-%m-%Y')

# Format 'Data/hora inici' to include only day, month, and year
# CORRECTED LINE: Remove format to allow pandas to infer the correct format
#df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'])
#df_fichas_crm['Data/hora inici'] = df_fichas_crm['Data/hora inici'].dt.strftime('%d-%m-%Y')

# Ensure df_merged1['createdAt'] also has the correct format before the final merge
# Apply the same formatting to df_merged1['createdAt'] and specify format
# using errors='coerce' to handle potential errors during conversion to datetime
# CHANGED LINE: Rename 'ContactId' to 'ContactId1' to match with df_fichas_crm
df_merged['createdAt'] = pd.to_datetime(df_merged['createdAt'], format='%d-%m-%Y', errors='coerce').dt.strftime('%d-%m-%Y')
df_merged1 = df_merged

# Realizar el LEFT JOIN sin renombrar ni crear columnas
df_merged_final = pd.merge(
    df_merged1,
    df_fichas_crm,
    how='left',
    left_on= [ 'fecha'], # Use ContactId1 to match df_tipificaciones's ContactId1
    right_on=[ 'fecha_str']
)


# Verificar el resultado
print(df_merged_final.head())

# Guardar el resultado en un nuevo archivo Excel
df_merged_final.to_excel('resultado_ficha_def.xlsx', index=False)
# Out:
# <ipython-input-21-1c41c18a4957>:14: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_time = df["createdAt"].dt.floor('10S')
# <ipython-input-21-1c41c18a4957>:26: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_time = df["createdAt"].dt.floor('10S')
# <ipython-input-21-1c41c18a4957>:53: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_time = df_fichas_crm["fecha"].dt.floor('10S')
#        id                                               body  read  secret  \
# 0   77623                                               Hola     1       0
# 1   77624  Benvingut/da a *Xat de suport emocional per a ...     1       0
# 2   77625                                   Me llamo sakhina     1       0
# 3   77626                                              Hola!     1       0
# 4   77627  Antes de empezar a chatear, es necesario que l...     1       0
# 5   77628                                             Acepto     1       0
# 6   77629  Gracias Sakhina. Soy maria jose, en que te pue...     1       0
# 7   77630                                Feliz año nuevo 🎆🎈🎊     1       0
# 8   77631                                              🥰🥰🥰🥰🥰     1       0
# 9   77632  Siento sola por eso dame la mensaje para nuevo...     1       0
# 10  77633  Feliz año nuevo! Que 2023 te traiga cosas buen...     1       0
# 11  77634                                            Gracias     1       0
# 12  77635                                              🥰🥰🥰🥰🥰     1       0
# 13  77636                          des de donde me escribes?     1       0
# 14  77637                                       En Barcelona     1       0
# 15  77638                                Y soy de Bangladesh     1       0
# 16  77639              entiendo que estas sola en barcelona.     1       0
# 17  77640                     estas estudiando o trabajando?     1       0
# 18  77641               Nada solamente estudiando castellano     1       0
# 19  77642        Este nuevo año quiero nuevo cosa en mi vida     1       0
#
#    direction              readAt  providerName  providerResponse  \
# 0         in 2023-01-01 00:11:06           NaN               NaN
# 1        out                 NaT           NaN               NaN
# 2         in 2023-01-01 00:11:07           NaN               NaN
# 3        out                 NaT           NaN               NaN
# 5   01/02/2023 20:40                  NaN      466.0         NaN       NaN
# 6   01/02/2023 23:45                  NaN      255.0         NaN       NaN
# 7   01/03/2023 03:58                  NaN      528.0         NaN       NaN
# 8   01/03/2023 03:58                  NaN      528.0         NaN       NaN
# 9   01/03/2023 13:52                  NaN      531.0         NaN       NaN
# 10  01/03/2023 14:32                  NaN      528.0         NaN       NaN
# 11  01/03/2023 21:33                  NaN      532.0         NaN       NaN
# 12  01/03/2023 23:55                  NaN      139.0         NaN       NaN
# 13  01/04/2023 21:39                  NaN      530.0         NaN       NaN
# 14  01/04/2023 00:34                  NaN      129.0         NaN       NaN
# 15  01/05/2023 18:45                  NaN      141.0         NaN       NaN
# 16  01/05/2023 18:47                  NaN      523.0         NaN       NaN
# 17  01/05/2023 20:42                  NaN      466.0         NaN       NaN
# 18  01/05/2023 23:58                  NaN      135.0         NaN       NaN
# 19  01/06/2023 01:34                  NaN      169.0         NaN       NaN
#
#                 Edat Gènere  ...  \
# 0                NaN   Dona  ...
# 1    De 18 a 35 anys   Dona  ...
# 2    De 18 a 35 anys   Dona  ...
# 3    De 18 a 35 anys   Home  ...
# 4    De 18 a 35 anys   Home  ...
# 5    De 18 a 35 anys   Dona  ...
# 6   Menor de 18 anys   Dona  ...
# 7    De 18 a 35 anys   Dona  ...
# 8    De 18 a 35 anys   Dona  ...
# 9                NaN   Dona  ...
# 10   De 36 a 65 anys   Dona  ...
# 11   De 18 a 35 anys    NaN  ...
# 12               NaN   Dona  ...
# 13   De 18 a 35 anys   Home  ...
# 14   De 18 a 35 anys   Dona  ...
# 15               NaN    NaN  ...
# 16               NaN    NaN  ...
# 17   De 18 a 35 anys   Dona  ...
# 18   De 18 a 35 anys   Home  ...
# 19   De 18 a 35 anys   Dona  ...
#
#       Vinculació: Si la resposta és “Sí”: Digues quin  \
# 0                                                 NaN
# 1                                           konsultam
# 2                                                 NaN
# 3                     Ja ha estat prèviament vinculat
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   SIS, servei d'atenció i suport a persones sens...
# 8   SIS, servei d'atenció i suport a persones sens...
# 9                                                 NaN
# 10                             Telèfon de l'Esperança
# 11  Konsulta,m del seu barri. També XaJoves sempre...
# 12                                                NaN
# 13                                                 TE
# 14                  La Tireta / Col.legi de Psicolegs
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                         Konsulta'm
# 19                                                NaN
#
#           QUÈ S’HA ACONSEGUIT  \
# 0   Companyia / socialització
# 1         Contenció emocional
# 2        Elaboració emocional
# 3        Elaboració emocional
# 4                           0
# 5   Companyia / socialització
# 6         Contenció emocional
# 7                           0
# 8                           0
# 9       Altres: (especificar)
# 10      Altres: (especificar)
# 11       Elaboració emocional
# 12                          0
# 13       Elaboració emocional
# 14       Elaboració emocional
# 15                          0
# 16                          0
# 17       Elaboració emocional
# 18       Elaboració emocional
# 19                          0
#
#                           QUÈ S’HA ACONSEGUIT. Altres  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Tècniques per ajudar-lo a controlar pensaments...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                         Donar informació del servei
# 10                              Informació del servei
# 11                               CAP- AQUÍ T´ESCOLTEM
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Activació serveis emergències: 116111 (Infància respon)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Mantenim el contacte pel xat fins que arriben els serveis d’emergència  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    fecha_y fecha_str rango2
# 0      NaT       NaN    NaN
# 1      NaT       NaN    NaN
# 2      NaT       NaN    NaN
# 3      NaT       NaN    NaN
# 4      NaT       NaN    NaN
#
# [5 rows x 77 columns]

# %%
import pandas as pd
import sqlite3

import pandas as pd

df_principal = pd.read_excel('/content/30.01.25 Uic.xlsx', sheet_name='Export')

# Crear DataFrame de ejemplo
#data = df_principal["createdAt"]
df = df_principal
import pandas as pd

# Convertir a datetime and assign to a new column in the DataFrame.
df["fecha"] = pd.to_datetime(df["createdAt"], format="%d/%m/%Y").dt.date

# Calcular inicio y fin del intervalo de 10 segundos
start_time = df["createdAt"].dt.floor('10S')
end_time = start_time + pd.Timedelta(seconds=10)

# Crear la variable de rango
df["rango"] = (
    start_time.dt.strftime("%H:%M:%S")
    + "-"
    + end_time.dt.strftime("%H:%M:%S")
)


print(df.head(20))
start_time = df["createdAt"].dt.floor('10S')
end_time = start_time + pd.Timedelta(seconds=10)

# Crear la variable de rango
df["rango_hora_10"] = (
    start_time.dt.strftime("%H:%M:%S")
    + "-"
    + end_time.dt.strftime("%H:%M:%S")
)

print(df.head(20))

# Cargar el archivo
df_fichas_crm = pd.read_excel('/content/20.02.25FichasCrm (2).xlsx')

# Convertir a datetime, permitiendo inferencia de formato
df_fichas_crm["fecha"] = pd.to_datetime(df_fichas_crm["Data/hora inici"], errors="coerce", dayfirst=True)

# Verificar si hay valores NaT (fechas no convertidas correctamente)
print("Valores NaT en fecha:")
print(df_fichas_crm[df_fichas_crm["fecha"].isna()][["Data/hora inici", "fecha"]])

# Crear una versión de la fecha en formato string (para mostrar, no para cálculos)
df_fichas_crm["fecha_str"] = df_fichas_crm["fecha"].dt.strftime("%d/%m/%Y")
df_fichas_crm = df_fichas_crm.rename(columns={'Número de telèfon de l’usuari': 'ContactId2'})

# Calcular inicio y fin del intervalo de 10 segundos (usando fecha en datetime)
start_time = df_fichas_crm["fecha"].dt.floor('10S')
end_time = start_time + pd.Timedelta(seconds=10)

# Crear la variable de rango
df_fichas_crm["rango2"] = (
    start_time.dt.strftime("%H:%M:%S")
    + "-"
    + end_time.dt.strftime("%H:%M:%S")
)

# Mostrar datos
print(df_fichas_crm.head(20))


# Cargar el archivo de tipificaciones (CSV)
df_tipificaciones = pd.read_excel('/content/20.02.25TipificacionesConversaciones.xlsx')
df_tipificaciones = df_tipificaciones.rename(columns={'ContactId': 'ContactId1'})

# Consulta SQL para hacer el LEFT JOIN con las transformaciones necesarias
query = """
SELECT
    p.*,
    t.ContactId1,
    f.ContactId2,

    -- Transformaciones de fecha en df_principal
    DATE(p.createdAt) AS fecha,
    strftime('%d/%m/%Y', p.createdAt) AS fecha_str,
    strftime('%d-%m-%Y', p.createdAt) AS createdAt_str,

    -- Cálculo de rango de 10 segundos en df_principal
    strftime('%H:%M:%S', p.createdAt) AS start_time,
    strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS end_time,
    strftime('%H:%M:%S', p.createdAt) || '-' || strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS rango,

    -- Transformaciones de fecha en df_fichas_crm
    DATE(f.`Data/hora inici`) AS fecha_date,
    strftime('%d/%m/%Y', f.`Data/hora inici`) AS fecha_str_fichas,
    strftime('%d-%m-%Y', f.`Data/hora inici`) AS Data_hora_inici_str,

    -- Cálculo de rango de 10 segundos en df_fichas_crm
    strftime('%H:%M:%S', f.`Data/hora inici`) AS start_time_fichas,
    strftime('%H:%M:%S', datetime(f.`Data/hora inici`, '+10 seconds')) AS end_time_fichas,
    strftime('%H:%M:%S', f.`Data/hora inici`) || '-' || strftime('%H:%M:%S', datetime(f.`Data/hora inici`, '+10 seconds')) AS rango2

FROM df_principal p
LEFT JOIN df_tipificaciones t
    ON p.OpenchannelInteractionId = t.id
    AND p.ContactId = t.ContactId1
LEFT JOIN df_fichas_crm f
    ON p.fecha = f.fecha_date
    OR p.fecha_str = f.fecha_str_fichas
    OR p.createdAt_str = f.Data_hora_inici_str
    OR p.rango = f.rango2;
"""

# Ejecutar la consulta y convertir el resultado en un DataFrame
df_merged_final = pd.read_sql_query(query, conn)

# Guardar el resultado en un archivo Excel
df_merged_final.to_excel('resultado_ficha_def.xlsx', index=False)

# Mostrar las primeras filas del resultado
print(df_merged_final.head())

# Cerrar la conexión a la base de datos
conn.close()
# Out:
# <ipython-input-23-507b3e4b93ee>:17: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_time = df["createdAt"].dt.floor('10S')
# <ipython-input-23-507b3e4b93ee>:29: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_time = df["createdAt"].dt.floor('10S')
# <ipython-input-23-507b3e4b93ee>:56: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_time = df_fichas_crm["fecha"].dt.floor('10S')
#        id                                               body  read  secret  \
# 0   77623                                               Hola     1       0
# 1   77624  Benvingut/da a *Xat de suport emocional per a ...     1       0
# 2   77625                                   Me llamo sakhina     1       0
# 3   77626                                              Hola!     1       0
# 4   77627  Antes de empezar a chatear, es necesario que l...     1       0
# 5   77628                                             Acepto     1       0
# 6   77629  Gracias Sakhina. Soy maria jose, en que te pue...     1       0
# 7   77630                                Feliz año nuevo 🎆🎈🎊     1       0
# 8   77631                                              🥰🥰🥰🥰🥰     1       0
# 9   77632  Siento sola por eso dame la mensaje para nuevo...     1       0
# 10  77633  Feliz año nuevo! Que 2023 te traiga cosas buen...     1       0
# 11  77634                                            Gracias     1       0
# 12  77635                                              🥰🥰🥰🥰🥰     1       0
# 13  77636                          des de donde me escribes?     1       0
# 14  77637                                       En Barcelona     1       0
# 18     20373                            65     01/05/2023 19:59
# 19     20377                           101     01/06/2023 01:18
#
#      Data/hora final  És un xat en blanc?  ContactId  Unnamed: 6  Projecte  \
# 0   01/01/2023 00:35                  NaN      466.0         NaN       NaN
# 1   01/01/2023 00:00                  NaN      300.0         NaN       NaN
# 2   01/01/2023 18:02                  NaN      300.0         NaN       NaN
# 3   01/02/2023 18:33                  NaN      394.0         NaN       NaN
# 4   01/02/2023 11:20                  NaN      526.0         NaN       NaN
# 5   01/02/2023 20:40                  NaN      466.0         NaN       NaN
# 6   01/02/2023 23:45                  NaN      255.0         NaN       NaN
# 7   01/03/2023 03:58                  NaN      528.0         NaN       NaN
# 8   01/03/2023 03:58                  NaN      528.0         NaN       NaN
# 9   01/03/2023 13:52                  NaN      531.0         NaN       NaN
# 10  01/03/2023 14:32                  NaN      528.0         NaN       NaN
# 11  01/03/2023 21:33                  NaN      532.0         NaN       NaN
# 12  01/03/2023 23:55                  NaN      139.0         NaN       NaN
# 13  01/04/2023 21:39                  NaN      530.0         NaN       NaN
# 14  01/04/2023 00:34                  NaN      129.0         NaN       NaN
# 15  01/05/2023 18:45                  NaN      141.0         NaN       NaN
# 16  01/05/2023 18:47                  NaN      523.0         NaN       NaN
# 17  01/05/2023 20:42                  NaN      466.0         NaN       NaN
# 18  01/05/2023 23:58                  NaN      135.0         NaN       NaN
# 19  01/06/2023 01:34                  NaN      169.0         NaN       NaN
#
#                 Edat Gènere  ...  \
# 0                NaN   Dona  ...
# 1    De 18 a 35 anys   Dona  ...
# 2    De 18 a 35 anys   Dona  ...
# 3    De 18 a 35 anys   Home  ...
# 4    De 18 a 35 anys   Home  ...
# 5    De 18 a 35 anys   Dona  ...
# 6   Menor de 18 anys   Dona  ...
# 7    De 18 a 35 anys   Dona  ...
# 8    De 18 a 35 anys   Dona  ...
# 9                NaN   Dona  ...
# 10   De 36 a 65 anys   Dona  ...
# 11   De 18 a 35 anys    NaN  ...
# 12               NaN   Dona  ...
# 13   De 18 a 35 anys   Home  ...
# 14   De 18 a 35 anys   Dona  ...
# 15               NaN    NaN  ...
# 16               NaN    NaN  ...
# 17   De 18 a 35 anys   Dona  ...
# 18   De 18 a 35 anys   Home  ...
# 19   De 18 a 35 anys   Dona  ...
#
#       Vinculació: Si la resposta és “Sí”: Digues quin  \
# 0                                                 NaN
# 1                                           konsultam
# 2                                                 NaN
# 3                     Ja ha estat prèviament vinculat
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   SIS, servei d'atenció i suport a persones sens...
# 8   SIS, servei d'atenció i suport a persones sens...
# 9                                                 NaN
# 10                             Telèfon de l'Esperança
# 11  Konsulta,m del seu barri. També XaJoves sempre...
# 12                                                NaN
# 13                                                 TE
# 14                  La Tireta / Col.legi de Psicolegs
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                
# 12 2023-03-01 23:23:00  01/03/2023  23:23:00-23:23:10
# 13 2023-04-01 19:41:00  01/04/2023  19:41:00-19:41:10
# 14 2023-04-01 23:32:00  01/04/2023  23:32:00-23:32:10
# 15 2023-05-01 14:39:00  01/05/2023  14:39:00-14:39:10
# 16 2023-05-01 15:00:00  01/05/2023  15:00:00-15:00:10
# 17 2023-05-01 17:22:00  01/05/2023  17:22:00-17:22:10
# 18 2023-05-01 19:59:00  01/05/2023  19:59:00-19:59:10
# 19 2023-06-01 01:18:00  01/06/2023  01:18:00-01:18:10
#
# [20 rows x 50 columns]
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such column: f.ContactId2
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-23-507b3e4b93ee> in <cell line: 0>()
#     111
#     112 # Ejecutar la consulta y convertir el resultado en un DataFrame
# --> 113 df_merged_final = pd.read_sql_query(query, conn)
#     114
#     115 # Guardar el resultado en un archivo Excel
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql '
# SELECT
#     p.*,
#     t.ContactId1,
#     f.ContactId2,
#
#     -- Transformaciones de fecha en df_principal
#     DATE(p.createdAt) AS fecha,
#     strftime('%d/%m/%Y', p.createdAt) AS fecha_str,
#     strftime('%d-%m-%Y', p.createdAt) AS createdAt_str,
#
#     -- Cálculo de rango de 10 segundos en df_principal
#     strftime('%H:%M:%S', p.createdAt) AS start_time,
#     strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS end_time,
#     strftime('%H:%M:%S', p.createdAt) || '-' || strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS rango,
#
#     -- Transformaciones de fecha en df_fichas_crm
#     DATE(f.`Data/hora inici`) AS fecha_date,
#     strftime('%d/%m/%Y', f.`Data/hora inici`) AS fecha_str_fichas,
#     strftime('%d-%m-%Y', f.`Data/hora inici`) AS Data_hora_inici_str,
#
#     -- Cálculo de rango de 10 segundos en df_fichas_crm
#     strftime('%H:%M:%S', f.`Data/hora inici`) AS start_time_fichas,
#     strftime('%H:%M:%S', datetime(f.`Data/hora inici`, '+10 seconds')) AS end_time_fichas,
#     strftime('%H:%M:%S', f.`Data/hora inici`) || '-' || strftime('%H:%M:%S', datetime(f.`Data/hora inici`, '+10 seconds')) AS rango2
#
# FROM df_principal p
# LEFT JOIN df_tipificaciones t
#     ON p.OpenchannelInteractionId = t.id
#     AND p.ContactId = t.ContactId1
# LEFT JOIN df_fichas_crm f
#     ON p.fecha = f.fecha_date
#     OR p.fecha_str = f.fecha_str_fichas
#     OR p.createdAt_str = f.Data_hora_inici_str
#     OR p.rango = f.rango2;
# ': no such column: f.ContactId2

# %%
import pandas as pd
import sqlite3

# Cargar los archivos en dataframes
df_principal = pd.read_excel('/content/30.01.25 Uic.xlsx', sheet_name='Export')
df_fichas_crm = pd.read_excel('/content/20.02.25FichasCrm (2).xlsx')
df_tipificaciones = pd.read_excel('/content/20.02.25TipificacionesConversaciones.xlsx')

# Asegurar que 'createdAt' es tipo datetime
df_principal["createdAt"] = pd.to_datetime(df_principal["createdAt"], errors='coerce', dayfirst=True)

# Crear columna de fecha
df_principal["fecha"] = df_principal["createdAt"].dt.date
df_principal["fecha_str"] = df_principal["createdAt"].dt.strftime("%d/%m/%Y")
df_principal["createdAt_str"] = df_principal["createdAt"].dt.strftime("%d-%m-%Y")

# Calcular rango de 10 segundos
start_time = df_principal["createdAt"].dt.floor('10S')
end_time = start_time + pd.Timedelta(seconds=10)
df_principal["rango"] = start_time.dt.strftime("%H:%M:%S") + "-" + end_time.dt.strftime("%H:%M:%S")

# Procesar df_fichas_crm
df_fichas_crm["fecha"] = pd.to_datetime(df_fichas_crm["Data/hora inici"], errors="coerce", dayfirst=True)
df_fichas_crm["fecha_str"] = df_fichas_crm["fecha"].dt.strftime("%d/%m/%Y")
df_fichas_crm["Data_hora_inici_str"] = df_fichas_crm["fecha"].dt.strftime("%d-%m-%Y")

# Calcular rango de 10 segundos en df_fichas_crm
start_time = df_fichas_crm["fecha"].dt.floor('10S')
end_time = start_time + pd.Timedelta(seconds=10)
df_fichas_crm["rango2"] = start_time.dt.strftime("%H:%M:%S") + "-" + end_time.dt.strftime("%H:%M:%S")

# Renombrar columnas para evitar conflictos en el JOIN
df_tipificaciones = df_tipificaciones.rename(columns={'ContactId': 'ContactId1'})
df_fichas_crm = df_fichas_crm.rename(columns={'Número de telèfon de l’usuari': 'ContactId2'})

# Crear conexión a SQLite en memoria
conn = sqlite3.connect(':memory:')

# Guardar DataFrames en la base de datos
df_principal.to_sql('df_principal', conn, index=False, if_exists='replace')
df_tipificaciones.to_sql('df_tipificaciones', conn, index=False, if_exists='replace')
df_fichas_crm.to_sql('df_fichas_crm', conn, index=False, if_exists='replace')

# Consulta SQL para hacer el LEFT JOIN con las transformaciones necesarias
query = """
SELECT
    p.*,
    t.ContactId1,
    f.ContactId2,

    -- Transformaciones de fecha en df_principal
    DATE(p.createdAt) AS fecha_sql,
    strftime('%d/%m/%Y', p.createdAt) AS fecha_str_sql,
    strftime('%d-%m-%Y', p.createdAt) AS createdAt_str_sql,

    -- Cálculo de rango de 10 segundos en df_principal
    strftime('%H:%M:%S', p.createdAt) AS start_time,
    strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS end_time,
    strftime('%H:%M:%S', p.createdAt) || '-' || strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS rango_sql,

    -- Transformaciones de fecha en df_fichas_crm
    DATE(f.fecha) AS fecha_date,
    strftime('%d/%m/%Y', f.fecha) AS fecha_str_fichas,
    strftime('%d-%m-%Y', f.fecha) AS Data_hora_inici_str,

    -- Cálculo de rango de 10 segundos en df_fichas_crm
    strftime('%H:%M:%S', f.fecha) AS start_time_fichas,
    strftime('%H:%M:%S', datetime(f.fecha, '+10 seconds')) AS end_time_fichas,
    strftime('%H:%M:%S', f.fecha) || '-' || strftime('%H:%M:%S', datetime(f.fecha, '+10 seconds')) AS rango2_sql

FROM df_principal p
LEFT JOIN df_tipificaciones t
    ON p.OpenchannelInteractionId = t.id
    AND p.ContactId = t.ContactId1
LEFT JOIN df_fichas_crm f
    ON p.fecha = f.fecha_date
    OR p.fecha_str = f.fecha_str_fichas
    OR p.createdAt_str = f.Data_hora_inici_str
    OR p.rango = f.rango2;
"""

# Ejecutar la consulta y convertir el resultado en un DataFrame
df_merged_final = pd.read_sql_query(query, conn)

# Guardar el resultado en un archivo Excel
df_merged_final.to_excel('resultado_ficha_def.xlsx', index=False)

# Mostrar las primeras filas del resultado
print(df_merged_final.head())

# Cerrar la conexión a la base de datos
conn.close()
# Out:
# <ipython-input-24-b1dffcd7bb20>:18: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_time = df_principal["createdAt"].dt.floor('10S')
# <ipython-input-24-b1dffcd7bb20>:28: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_time = df_fichas_crm["fecha"].dt.floor('10S')
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such column: f.ContactId2
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-24-b1dffcd7bb20> in <cell line: 0>()
#      81
#      82 # Ejecutar la consulta y convertir el resultado en un DataFrame
# ---> 83 df_merged_final = pd.read_sql_query(query, conn)
#      84
#      85 # Guardar el resultado en un archivo Excel
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql '
# SELECT
#     p.*,
#     t.ContactId1,
#     f.ContactId2,
#
#     -- Transformaciones de fecha en df_principal
#     DATE(p.createdAt) AS fecha_sql,
#     strftime('%d/%m/%Y', p.createdAt) AS fecha_str_sql,
#     strftime('%d-%m-%Y', p.createdAt) AS createdAt_str_sql,
#
#     -- Cálculo de rango de 10 segundos en df_principal
#     strftime('%H:%M:%S', p.createdAt) AS start_time,
#     strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS end_time,
#     strftime('%H:%M:%S', p.createdAt) || '-' || strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS rango_sql,
#
#     -- Transformaciones de fecha en df_fichas_crm
#     DATE(f.fecha) AS fecha_date,
#     strftime('%d/%m/%Y', f.fecha) AS fecha_str_fichas,
#     strftime('%d-%m-%Y', f.fecha) AS Data_hora_inici_str,
#
#     -- Cálculo de rango de 10 segundos en df_fichas_crm
#     strftime('%H:%M:%S', f.fecha) AS start_time_fichas,
#     strftime('%H:%M:%S', datetime(f.fecha, '+10 seconds')) AS end_time_fichas,
#     strftime('%H:%M:%S', f.fecha) || '-' || strftime('%H:%M:%S', datetime(f.fecha, '+10 seconds')) AS rango2_sql
#
# FROM df_principal p
# LEFT JOIN df_tipificaciones t
#     ON p.OpenchannelInteractionId = t.id
#     AND p.ContactId = t.ContactId1
# LEFT JOIN df_fichas_crm f
#     ON p.fecha = f.fecha_date
#     OR p.fecha_str = f.fecha_str_fichas
#     OR p.createdAt_str = f.Data_hora_inici_str
#     OR p.rango = f.rango2;
# ': no such column: f.ContactId2

# %%
import pandas as pd
import sqlite3

# Cargar los archivos en dataframes
df_principal = pd.read_excel('/content/30.01.25 Uic.xlsx', sheet_name='Export')
df_fichas_crm = pd.read_excel('/content/20.02.25FichasCrm (2).xlsx')
df_tipificaciones = pd.read_excel('/content/20.02.25TipificacionesConversaciones.xlsx')

# Verificar nombres de columnas antes de renombrar
print("Columnas en df_fichas_crm antes de renombrar:", df_fichas_crm.columns)

# Renombrar la columna del número de teléfono si existe
if 'Número de telèfon de l’usuari' in df_fichas_crm.columns:
    df_fichas_crm = df_fichas_crm.rename(columns={'Número de telèfon de l’usuari': 'ContactId2'})

# Verificar nombres de columnas después de renombrar
print("Columnas en df_fichas_crm después de renombrar:", df_fichas_crm.columns)

# Convertir fechas en df_principal
df_principal["createdAt"] = pd.to_datetime(df_principal["createdAt"], errors='coerce', dayfirst=True)
df_principal["fecha"] = df_principal["createdAt"].dt.date
df_principal["fecha_str"] = df_principal["createdAt"].dt.strftime("%d/%m/%Y")
df_principal["createdAt_str"] = df_principal["createdAt"].dt.strftime("%d-%m-%Y")

# Calcular rango de 10 segundos en df_principal
start_time = df_principal["createdAt"].dt.floor('10S')
end_time = start_time + pd.Timedelta(seconds=10)
df_principal["rango"] = start_time.dt.strftime("%H:%M:%S") + "-" + end_time.dt.strftime("%H:%M:%S")

# Convertir fechas en df_fichas_crm
df_fichas_crm["fecha"] = pd.to_datetime(df_fichas_crm["Data/hora inici"], errors="coerce", dayfirst=True)
df_fichas_crm["fecha_str"] = df_fichas_crm["fecha"].dt.strftime("%d/%m/%Y")
df_fichas_crm["Data_hora_inici_str"] = df_fichas_crm["fecha"].dt.strftime("%d-%m-%Y")

# Calcular rango de 10 segundos en df_fichas_crm
start_time = df_fichas_crm["fecha"].dt.floor('10S')
end_time = start_time + pd.Timedelta(seconds=10)
df_fichas_crm["rango2"] = start_time.dt.strftime("%H:%M:%S") + "-" + end_time.dt.strftime("%H:%M:%S")

# Renombrar columnas en df_tipificaciones
df_tipificaciones = df_tipificaciones.rename(columns={'ContactId': 'ContactId1'})

# Crear conexión a SQLite en memoria
conn = sqlite3.connect(':memory:')

# Guardar DataFrames en la base de datos
df_principal.to_sql('df_principal', conn, index=False, if_exists='replace')
df_tipificaciones.to_sql('df_tipificaciones', conn, index=False, if_exists='replace')
df_fichas_crm.to_sql('df_fichas_crm', conn, index=False, if_exists='replace')

# Revisar columnas en SQLite antes del JOIN
print("Columnas en df_fichas_crm después de guardar en SQL:")
df_check = pd.read_sql_query("PRAGMA table_info(df_fichas_crm);", conn)
print(df_check)

# Consulta SQL para hacer el LEFT JOIN con las transformaciones necesarias
query = """
SELECT
    p.*,
    t.ContactId1,
    f.ContactId2,

    -- Transformaciones de fecha en df_principal
    DATE(p.createdAt) AS fecha_sql,
    strftime('%d/%m/%Y', p.createdAt) AS fecha_str_sql,
    strftime('%d-%m-%Y', p.createdAt) AS createdAt_str_sql,

    -- Cálculo de rango de 10 segundos en df_principal
    strftime('%H:%M:%S', p.createdAt) AS start_time,
    strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS end_time,
    strftime('%H:%M:%S', p.createdAt) || '-' || strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS rango_sql,

    -- Transformaciones de fecha en df_fichas_crm
    DATE(f.fecha) AS fecha_date,
    strftime('%d/%m/%Y', f.fecha) AS fecha_str_fichas,
    strftime('%d-%m-%Y', f.fecha) AS Data_hora_inici_str,

    -- Cálculo de rango de 10 segundos en df_fichas_crm
    strftime('%H:%M:%S', f.fecha) AS start_time_fichas,
    strftime('%H:%M:%S', datetime(f.fecha, '+10 seconds')) AS end_time_fichas,
    strftime('%H:%M:%S', f.fecha) || '-' || strftime('%H:%M:%S', datetime(f.fecha, '+10 seconds')) AS rango2_sql

FROM df_principal p
LEFT JOIN df_tipificaciones t
    ON p.OpenchannelInteractionId = t.id
    AND p.ContactId = t.ContactId1
LEFT JOIN df_fichas_crm f
    ON p.fecha = f.fecha_date
    OR p.fecha_str = f.fecha_str_fichas
    OR p.createdAt_str = f.Data_hora_inici_str
    OR p.rango = f.rango2;
"""

# Ejecutar la consulta y convertir el resultado en un DataFrame
try:
    df_merged_final = pd.read_sql_query(query, conn)
    print(df_merged_final.head())
except Exception as e:
    print("Error en la consulta SQL:", e)

# Guardar el resultado en un archivo Excel
df_merged_final.to_excel('resultado_ficha_def.xlsx', index=False)

# Cerrar la conexión a la base de datos
conn.close()
# Out:
# Columnas en df_fichas_crm antes de renombrar: Index(['ID fitxa', 'ID voluntari / Nom voluntari', 'Data/hora inici',
#        'Data/hora final', 'És un xat en blanc?', 'ContactId', 'Unnamed: 6',
#        'Projecte', 'Edat', 'Gènere', 'País de naixement', 'Barri/Districte',
#        'Població', 'Província', 'Comunitat Autònoma',
#        'Trucada de fora d’Espanya', 'Unitat de convivència',
#        'Nivell d’estudis', 'Situació laboral', 'Problemàtica', 'Altres',
#        'Block Ideació suïcida: Carrera suïcida',
#        'Block Ideació suïcida: Ha pensat que seria millor morir-se o ha desitjat estar mort?',
#        'Block Ideació suïcida: Ha volgut fer-se mal?',
#        'Block Ideació suïcida: Ha pensat en el suïcidi?',
#        'Block Ideació suïcida: Ha planejat (planificat) com suïcidar-se?',
#        'Block Ideació suïcida: Ha intentat suicidar-se?',
#        'Block Ideació suïcida: Al llarg de la seva vida: Alguna vegada ha intentat suicidar-se?',
#        'Block Problemes de salut mental: Està diagnosticat?',
#        'Block Problemes de salut mental: Està diagnosticat. Quin',
#        'Block Problemes de salut mental: Pren medicació?',
#        'Block Problemes de salut mental: Pren medicació. Quina',
#        'QUÈ EXPRESSA LA PERSONA QUE XATEJA I OBSERVACIONS', 'ESTAT EMOCIONAL',
#        'Vinculació: Serveis Salut (públics i privats)',
#        'Vinculació: Serveis Socials (públics)',
#        'Vinculació: Teixit Associatiu (entitats privades i públiques)',
#        'Vinculació: No',
#        'Vinculació: No s’ha pogut conèixer aquesta informació',
#        'Vinculació: S’ha ofert informació d’algun recurs',
#        'Vinculació: Si la resposta és “Sí”: Digues quin',
#        'QUÈ S’HA ACONSEGUIT', 'QUÈ S’HA ACONSEGUIT. Altres',
#        'Activació serveis emergències: 061',
#        'Activació serveis emergències: 112 / 116 (Emergències Andorra)',
#        'Activació serveis emergències: 116111 (Infància respon)',
#        'Mantenim el contacte pel xat fins que arriben els serveis d’emergència'],
#       dtype='object')
# Columnas en df_fichas_crm después de renombrar: Index(['ID fitxa', 'ID voluntari / Nom voluntari', 'Data/hora inici',
#        'Data/hora final', 'És un xat en blanc?', 'ContactId', 'Unnamed: 6',
#        'Projecte', 'Edat', 'Gènere', 'País de naixement', 'Barri/Districte',
#        'Població', 'Província', 'Comunitat Autònoma',
#        'Trucada de fora d’Espanya', 'Unitat de convivència',
#        'Nivell d’estudis', 'Situació laboral', 'Problemàtica', 'Altres',
#        'Block Ideació suïcida: Carrera suïcida',
#        'Block Ideació suïcida: Ha pensat que seria millor morir-se o ha desitjat estar mort?',
#        'Block Ideació suïcida: Ha volgut fer-se mal?',
#        'Block Ideació suïcida: Ha pensat en el suïcidi?',
#        'Block Ideació suïcida: Ha planejat (planificat) com suïcidar-se?',
#        'Block Ideació suïcida: Ha intentat suicidar-se?',
#        'Block Ideació suïcida: Al llarg de la seva vida: Alguna vegada ha intentat suicidar-se?',
#        'Block Problemes de salut mental: Està diagnosticat?',
#        'Block Problemes de salut mental: Està diagnosticat. Quin',
#        'Block Problemes de salut mental: Pren medicació?',
#        'Block Problemes de salut mental: Pren medicació. Quina',
#        'QUÈ EXPRESSA LA PERSONA QUE XATEJA I OBSERVACIONS', 'ESTAT EMOCIONAL',
#        'Vinculació: Serveis Salut (públics i privats)',
#        'Vinculació: Serveis Socials (públics)',
#        'Vinculació: Teixit Associatiu (entitats privades i públiques)',
#        'Vinculació: No',
#        'Vinculació: No s’ha pogut conèixer aquesta informació',
#        'Vinculació: S’ha ofert informació d’algun recurs',
#        'Vinculació: Si la resposta és “Sí”: Digues quin',
#        'QUÈ S’HA ACONSEGUIT', 'QUÈ S’HA ACONSEGUIT. Altres',
#        'Activació serveis emergències: 061',
#        'Activació serveis emergències: 112 / 116 (Emergències Andorra)',
#        'Activació serveis emergències: 116111 (Infància respon)',
#        'Mantenim el contacte pel xat fins que arriben els serveis d’emergència'],
#       dtype='object')
# <ipython-input-25-d9a67fc5481d>:26: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_time = df_principal["createdAt"].dt.floor('10S')
# <ipython-input-25-d9a67fc5481d>:36: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   start_time = df_fichas_crm["fecha"].dt.floor('10S')
# Columnas en df_fichas_crm después de guardar en SQL:
#     cid                                               name       type  \
# 0     0                                           ID fitxa    INTEGER
# 1     1                       ID voluntari / Nom voluntari    INTEGER
# 2     2                                    Data/hora inici       TEXT
# 3     3                                    Data/hora final       TEXT
# 4     4                                És un xat en blanc?       REAL
# 5     5                                          ContactId       REAL
# 6     6                                         Unnamed: 6       REAL
# 7     7                                           Projecte       REAL
# 8     8                                               Edat       TEXT
# 9     9                                             Gènere       TEXT
# 10   10                                  País de naixement       REAL
# 11   11                                    Barri/Districte       REAL
# 12   12                                           Població       TEXT
# 13   13                                          Província       TEXT
# 14   14                                 Comunitat Autònoma       TEXT
# 15   15                          Trucada de fora d’Espanya       TEXT
# 16   16                              Unitat de convivència       TEXT
# 17   17                                   Nivell d’estudis       TEXT
# 18   18                                   Situació laboral       TEXT
# 19   19                                       Problemàtica       TEXT
# 20   20                                             Altres       TEXT
# 21   21             Block Ideació suïcida: Carrera suïcida       TEXT
# 22   22  Block Ideació suïcida: Ha pensat que seria mil...       TEXT
# 23   23       Block Ideació suïcida: Ha volgut fer-se mal?       TEXT
# 24   24    Block Ideació suïcida: Ha pensat en el suïcidi?       TEXT
# 25   25  Block Ideació suïcida: Ha planejat (planificat...       TEXT
# 26   26    Block Ideació suïcida: Ha intentat suicidar-se?       TEXT
# 27   27  Block Ideació suïcida: Al llarg de la seva vid...       TEXT
# 28   28  Block Problemes de salut mental: Està diagnost...       TEXT
# 29   29  Block Problemes de salut mental: Està diagnost...       TEXT
# 30   30   Block Problemes de salut mental: Pren medicació?       TEXT
# 31   31  Block Problemes de salut mental: Pren medicaci...       TEXT
# 32   32  QUÈ EXPRESSA LA PERSONA QUE XATEJA I OBSERVACIONS       TEXT
# 33   33                                    ESTAT EMOCIONAL       TEXT
# 34   34      Vinculació: Serveis Salut (públics i privats)       TEXT
# 35   35              Vinculació: Serveis Socials (públics)       TEXT
# 36   36  Vinculació: Teixit Associatiu (entitats privad...       TEXT
# 37   37                                     Vinculació: No       TEXT
# 38   38  Vinculació: No s’ha pogut conèixer aquesta inf...       TEXT
# 39   39   Vinculació: S’ha ofert informació d’algun recurs       TEXT
# 40   40    Vinculació: Si la resposta és “Sí”: Digues quin       TEXT
# 41   41                                QUÈ S’HA ACONSEGUIT       TEXT
# 42   42                        QUÈ S’HA ACONSEGUIT. Altres       TEXT
# 43   43                 Activació serveis emergències: 061       TEXT
# 44   44  Activació serveis emergències: 112 / 116 (Emer...       TEXT
# 45   45  Activació serveis emergències: 116111 (Infànci...       TEXT
# 46   46  Mantenim el contacte pel xat fins que arriben ...       TEXT
# 47   47                                              fecha  TIMESTAMP
# 48   48                                          fecha_str       TEXT
# 49   49                                Data_hora_inici_str       TEXT
# 50   50                                             rango2       TEXT
#
#     notnull dflt_value  pk
# 0         0       None   0
# 1         0       None   0
# 2         0       None   0
# 3         0       None   0
# 4         0       None   0
# 5         0       None   0
# 6         0       None   0
# 7         0       None   0
# 8         0       None   0
# 9         0       None   0
# 10        0       None   0
# 11        0       None   0
# 12        0       None   0
# 13        0       None   0
# 14        0       None   0
# 15        0       None   0
# 16        0       None   0
# 17        0       None   0
# 18        0       None   0
# 19        0       None   0
# 20        0       None   0
# 21        0       None   0
# 22        0       None   0
# 23        0       None   0
# 24        0       None   0
# 25        0       None   0
# 26        0       None   0
# 27        0       None   0
# 28        0       None   0
# 29        0       None   0
# 30        0       None   0
# 31        0       None   0
# 32        0       None   0
# 33        0       None   0
# 34        0       None   0
# 35        0       None   0
# 36        0       None   0
# 37        0       None   0
# 38        0       None   0
# 39        0       None   0
# 40        0       None   0
# 41        0       None   0
# 42        0       None   0
# 43        0       None   0
# 44        0       None   0
# 45        0       None   0
# 46        0       None   0
# 47        0       None   0
# 48        0       None   0
# 49        0       None   0
# 50        0       None   0
# Error en la consulta SQL: Execution failed on sql '
# SELECT
#     p.*,
#     t.ContactId1,
#     f.ContactId2,
#
#     -- Transformaciones de fecha en df_principal
#     DATE(p.createdAt) AS fecha_sql,
#     strftime('%d/%m/%Y', p.createdAt) AS fecha_str_sql,
#     strftime('%d-%m-%Y', p.createdAt) AS createdAt_str_sql,
#
#     -- Cálculo de rango de 10 segundos en df_principal
#     strftime('%H:%M:%S', p.createdAt) AS start_time,
#     strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS end_time,
#     strftime('%H:%M:%S', p.createdAt) || '-' || strftime('%H:%M:%S', datetime(p.createdAt, '+10 seconds')) AS rango_sql,
#
#     -- Transformaciones de fecha en df_fichas_crm
#     DATE(f.fecha) AS fecha_date,
#     strftime('%d/%m/%Y', f.fecha) AS fecha_str_fichas,
#     strftime('%d-%m-%Y', f.fecha) AS Data_hora_inici_str,
#
#     -- Cálculo de rango de 10 segundos en df_fichas_crm
#     strftime('%H:%M:%S', f.fecha) AS start_time_fichas,
#     strftime('%H:%M:%S', datetime(f.fecha, '+10 seconds')) AS end_time_fichas,
#     strftime('%H:%M:%S', f.fecha) || '-' || strftime('%H:%M:%S', datetime(f.fecha, '+10 seconds')) AS rango2_sql
#
# FROM df_principal p
# LEFT JOIN df_tipificaciones t
#     ON p.OpenchannelInteractionId = t.id
#     AND p.ContactId = t.ContactId1
# LEFT JOIN df_fichas_crm f
#     ON p.fecha = f.fecha_date
#     OR p.fecha_str = f.fecha_str_fichas
#     OR p.createdAt_str = f.Data_hora_inici_str
#     OR p.rango = f.rango2;
# ': no such column: f.ContactId2
