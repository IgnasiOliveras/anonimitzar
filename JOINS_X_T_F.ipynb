# %% [markdown]
# <a href="https://colab.research.google.com/github/IgnasiOliveras/anonimitzar/blob/main/JOINS_X_T_F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_principal = pd.read_excel('/content/30.01.25 Uic.xlsx', sheet_name='Export')
# subset_df = df_principal[df_principal['OpenchannelInteractionId'] == 1489]

# Cargar la hoja "Export" del archivo 30.01.25_Uic.xlsx
# df_principal = subset_df

# Cargar el archivo de tipificaciones (CSV)
df_tipificaciones = pd.read_excel('/content/20.02.25TipificacionesConversaciones.xlsx')

# Realizar el LEFT JOIN
df_merged = pd.merge(
    df_principal,
    df_tipificaciones,
    how='left',
    left_on=['OpenchannelInteractionId', 'ContactId'],
    right_on=['id', 'ContactId']
)

# Verificar el resultado
print(df_merged.head())

# Guardar el resultado en un nuevo archivo CSV (opcional)
df_merged.to_csv('resultado_left_join.csv', index=False)

# 1️⃣ Cargar el archivo resultado del primer JOIN
df_merged1 = df_merged

# 2️⃣ Cargar el archivo de Fichas CRM (suponiendo que es Excel)
df_fichas_crm = pd.read_excel('/content/20.02.25FichasCrm (2).xlsx')  # Ajusta el número de hoja si es necesario

# Convert 'createdAt' to datetime if it's not already
df_merged1['createdAt'] = pd.to_datetime(df_merged1['createdAt'])

# Convert 'Data/hora inici' to datetime
df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'])

# Realizar el LEFT JOIN sin renombrar ni crear columnas
df_merged_final = pd.merge(
    df_merged1,
    df_fichas_crm,
    how='left',
    left_on= ['ContactId','createdAt'],
    right_on=['ContactId','Data/hora inici']
)

# Verificar el resultado
print(df_merged_final.head())

# Guardar el resultado en un nuevo archivo Excel
df_merged_final.to_excel('resultado_ficha_1489.xlsx', index=False)

# %%
# prompt: change the format of the variable createdAt of the df_principal to only include the day month and year and delete the time. Do the same to the variable Data/hora inici of the dataframe df_fichas_crm

# Convert 'createdAt' to datetime if it's not already
df_principal['createdAt'] = pd.to_datetime(df_principal['createdAt'])

# Format 'createdAt' to include only day, month, and year
df_principal['createdAt'] = df_principal['createdAt'].dt.strftime('%d-%m-%Y')

# Format 'Data/hora inici' to include only day, month, and year
df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'])
df_fichas_crm['Data/hora inici'] = df_fichas_crm['Data/hora inici'].dt.strftime('%d-%m-%Y')

# %%
# Realizar el LEFT JOIN
df_merged = pd.merge(
    df_principal,
    df_tipificaciones,
    how='left',
    left_on=['OpenchannelInteractionId', 'ContactId'],
    right_on=['id', 'ContactId']
)

# Verificar el resultado
print(df_merged.head())

# Guardar el resultado en un nuevo archivo CSV (opcional)
df_merged.to_csv('resultado_left_join.csv', index=False)


# Realizar el LEFT JOIN sin renombrar ni crear columnas
df_merged_final = pd.merge(
    df_merged1,
    df_fichas_crm,
    how='left',
    left_on= ['ContactId','createdAt'],
    right_on=['ContactId','Data/hora inici']
)

# Verificar el resultado
print(df_merged_final.head())

# Guardar el resultado en un nuevo archivo Excel
df_merged_final.to_excel('resultado_ficha_1489.xlsx', index=False)
# Out:
#     id_x                                               body  read  secret  \
# 0  77623                                               Hola     1       0
# 1  77624  Benvingut/da a *Xat de suport emocional per a ...     1       0
# 2  77625                                   Me llamo sakhina     1       0
# 3  77626                                              Hola!     1       0
# 4  77627  Antes de empezar a chatear, es necesario que l...     1       0
#
#   direction              readAt  providerName  providerResponse   createdAt  \
# 0        in 2023-01-01 00:11:06           NaN               NaN  01-01-2023
# 1       out                 NaT           NaN               NaN  01-01-2023
# 2        in 2023-01-01 00:11:07           NaN               NaN  01-01-2023
# 3       out                 NaT           NaN               NaN  01-01-2023
# 4       out                 NaT           NaN               NaN  01-01-2023
#
#             updatedAt  ...  ContactId  AttachmentId  integrationId  \
# 0 2023-01-01 00:11:06  ...        466           NaN            NaN
# 1 2023-01-01 00:10:19  ...        466           NaN            NaN
# 2 2023-01-01 00:11:07  ...        466           NaN            NaN
# 3 2023-01-01 00:11:12  ...        466           NaN            NaN
# 4 2023-01-01 00:11:33  ...        466           NaN            NaN
#
#    parentIntegrationId  sentBy  id_y  closed            closedAt  \
# 0                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 1                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 2                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 3                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 4                  NaN     NaN  1489       1 2023-01-01 00:35:18
#
#       disposition  note
# 0  Conversa atesa   NaN
# 1  Conversa atesa   NaN
# 2  Conversa atesa   NaN
# 3  Conversa atesa   NaN
# 4  Conversa atesa   NaN
#
# [5 rows x 23 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-b3cadf4191ae> in <cell line: 0>()
#      16
#      17 # Realizar el LEFT JOIN sin renombrar ni crear columnas
# ---> 18 df_merged_final = pd.merge(
#      19     df_merged1,
#      20     df_fichas_crm,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     805         # validate the merge keys dtypes. We may need to coerce
#     806         # to avoid incompatible dtypes
# --> 807         self._maybe_coerce_merge_keys()
#     808
#     809         # If argument passed to validate,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1510             # datetimelikes must match exactly
#    1511             elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
# -> 1512                 raise ValueError(msg)
#    1513             elif not needs_i8_conversion(lk.dtype) and needs_i8_conversion(rk.dtype):
#    1514                 raise ValueError(msg)
#
# ValueError: You are trying to merge on datetime64[ns] and object columns for key 'createdAt'. If you wish to proceed you should use pd.concat

# %%
# Convert 'createdAt' to datetime if it's not already
df_principal['createdAt'] = pd.to_datetime(df_principal['createdAt'])

# Format 'createdAt' to include only day, month, and year
df_principal['createdAt'] = df_principal['createdAt'].dt.strftime('%d-%m-%Y')

# Format 'Data/hora inici' to include only day, month, and year
df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'])
df_fichas_crm['Data/hora inici'] = df_fichas_crm['Data/hora inici'].dt.strftime('%d-%m-%Y')

# Ensure df_merged1['createdAt'] also has the correct format before the final merge
df_merged1['createdAt'] = pd.to_datetime(df_merged1['createdAt']).dt.strftime('%d-%m-%Y') # Apply the same formatting to df_merged1['createdAt']

# Realizar el LEFT JOIN sin renombrar ni crear columnas
df_merged_final = pd.merge(
    df_merged1,
    df_fichas_crm,
    how='left',
    left_on= ['ContactId','createdAt'],
    right_on=['ContactId','Data/hora inici']
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-030b44412879> in <cell line: 0>()
#       1 # Convert 'createdAt' to datetime if it's not already
# ----> 2 df_principal['createdAt'] = pd.to_datetime(df_principal['createdAt'])
#       3
#       4 # Format 'createdAt' to include only day, month, and year
#       5 df_principal['createdAt'] = df_principal['createdAt'].dt.strftime('%d-%m-%Y')
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061                 result = arg.tz_localize("utc")
#    1062     elif isinstance(arg, ABCSeries):
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064         if not cache_array.empty:
#    1065             result = arg.map(cache_array)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     245         unique_dates = unique(arg)
#     246         if len(unique_dates) < len(arg):
# --> 247             cache_dates = convert_listlike(unique_dates, format)
#     248             # GH#45319
#     249             try:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431     # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432     if format is not None and format != "mixed":
# --> 433         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     434
#     435     result, tz_parsed = objects_to_datetime64(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "13-01-2023" doesn't match format "%m-%d-%Y", at position 12. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
# Convert 'createdAt' to datetime if it's not already
df_principal['createdAt'] = pd.to_datetime(df_principal['createdAt'], format='%d-%m-%Y') # Specify the format

# Format 'createdAt' to include only day, month, and year
df_principal['createdAt'] = df_principal['createdAt'].dt.strftime('%d-%m-%Y')

# Format 'Data/hora inici' to include only day, month, and year
df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'])
df_fichas_crm['Data/hora inici'] = df_fichas_crm['Data/hora inici'].dt.strftime('%d-%m-%Y')

# Ensure df_merged1['createdAt'] also has the correct format before the final merge
df_merged1['createdAt'] = pd.to_datetime(df_merged1['createdAt'], format='%d-%m-%Y').dt.strftime('%d-%m-%Y') # Apply the same formatting to df_merged1['createdAt'] and specify format

# Realizar el LEFT JOIN sin renombrar ni crear columnas
df_merged_final = pd.merge(
    df_merged1,
    df_fichas_crm,
    how='left',
    left_on= ['ContactId','createdAt'],
    right_on=['ContactId','Data/hora inici']
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-480a30abbfad> in <cell line: 0>()
#       6
#       7 # Format 'Data/hora inici' to include only day, month, and year
# ----> 8 df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'])
#       9 df_fichas_crm['Data/hora inici'] = df_fichas_crm['Data/hora inici'].dt.strftime('%d-%m-%Y')
#      10
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061                 result = arg.tz_localize("utc")
#    1062     elif isinstance(arg, ABCSeries):
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064         if not cache_array.empty:
#    1065             result = arg.map(cache_array)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     245         unique_dates = unique(arg)
#     246         if len(unique_dates) < len(arg):
# --> 247             cache_dates = convert_listlike(unique_dates, format)
#     248             # GH#45319
#     249             try:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431     # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432     if format is not None and format != "mixed":
# --> 433         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     434
#     435     result, tz_parsed = objects_to_datetime64(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "13-01-2023" doesn't match format "%m-%d-%Y", at position 12. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
import pandas as pd

df_principal = pd.read_excel('/content/30.01.25 Uic.xlsx', sheet_name='Export')
# subset_df = df_principal[df_principal['OpenchannelInteractionId'] == 1489]

# Cargar la hoja "Export" del archivo 30.01.25_Uic.xlsx
# df_principal = subset_df

# Cargar el archivo de tipificaciones (CSV)
df_tipificaciones = pd.read_excel('/content/20.02.25TipificacionesConversaciones.xlsx')

# 2️⃣ Cargar el archivo de Fichas CRM (suponiendo que es Excel)
df_fichas_crm = pd.read_excel('/content/20.02.25FichasCrm (2).xlsx')

# Realizar el LEFT JOIN
df_merged = pd.merge(
    df_principal,
    df_tipificaciones,
    how='left',
    left_on=['OpenchannelInteractionId', 'ContactId'],
    right_on=['id', 'ContactId']
)

# Verificar el resultado
print(df_merged.head())

# Guardar el resultado en un nuevo archivo CSV (opcional)
df_merged.to_csv('resultado_left_join.csv', index=False)

# Convert 'createdAt' to datetime if it's not already
df_principal['createdAt'] = pd.to_datetime(df_principal['createdAt'], format='%d-%m-%Y') # Specify the format

# Format 'createdAt' to include only day, month, and year
df_principal['createdAt'] = df_principal['createdAt'].dt.strftime('%d-%m-%Y')

# Format 'Data/hora inici' to include only day, month, and year
# CORRECTED LINE: Specify the correct format string ('%d-%m-%Y')
df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'], format='%d-%m-%Y')
df_fichas_crm['Data/hora inici'] = df_fichas_crm['Data/hora inici'].dt.strftime('%d-%m-%Y')

# Ensure df_merged1['createdAt'] also has the correct format before the final merge
df_merged1['createdAt'] = pd.to_datetime(df_merged1['createdAt'], format='%d-%m-%Y').dt.strftime('%d-%m-%Y') # Apply the same formatting to df_merged1['createdAt'] and specify format

# Realizar el LEFT JOIN sin renombrar ni crear columnas
df_merged_final = pd.merge(
    df_merged1,
    df_fichas_crm,
    how='left',
    left_on= ['ContactId','createdAt'],
    right_on=['ContactId','Data/hora inici']
)


# Verificar el resultado
print(df_merged_final.head())

# Guardar el resultado en un nuevo archivo Excel
df_merged_final.to_excel('resultado_ficha_1489.xlsx', index=False)
# Out:
#     id_x                                               body  read  secret  \
# 0  77623                                               Hola     1       0
# 1  77624  Benvingut/da a *Xat de suport emocional per a ...     1       0
# 2  77625                                   Me llamo sakhina     1       0
# 3  77626                                              Hola!     1       0
# 4  77627  Antes de empezar a chatear, es necesario que l...     1       0
#
#   direction              readAt  providerName  providerResponse  \
# 0        in 2023-01-01 00:11:06           NaN               NaN
# 1       out                 NaT           NaN               NaN
# 2        in 2023-01-01 00:11:07           NaN               NaN
# 3       out                 NaT           NaN               NaN
# 4       out                 NaT           NaN               NaN
#
#             createdAt           updatedAt  ...  ContactId  AttachmentId  \
# 0 2023-01-01 00:10:19 2023-01-01 00:11:06  ...        466           NaN
# 1 2023-01-01 00:10:19 2023-01-01 00:10:19  ...        466           NaN
# 2 2023-01-01 00:10:37 2023-01-01 00:11:07  ...        466           NaN
# 3 2023-01-01 00:11:12 2023-01-01 00:11:12  ...        466           NaN
# 4 2023-01-01 00:11:33 2023-01-01 00:11:33  ...        466           NaN
#
#    integrationId  parentIntegrationId  sentBy  id_y  closed  \
# 0            NaN                  NaN     NaN  1489       1
# 1            NaN                  NaN     NaN  1489       1
# 2            NaN                  NaN     NaN  1489       1
# 3            NaN                  NaN     NaN  1489       1
# 4            NaN                  NaN     NaN  1489       1
#
#              closedAt     disposition  note
# 0 2023-01-01 00:35:18  Conversa atesa   NaN
# 1 2023-01-01 00:35:18  Conversa atesa   NaN
# 2 2023-01-01 00:35:18  Conversa atesa   NaN
# 3 2023-01-01 00:35:18  Conversa atesa   NaN
# 4 2023-01-01 00:35:18  Conversa atesa   NaN
#
# [5 rows x 23 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-363a88269684> in <cell line: 0>()
#      36 # Format 'Data/hora inici' to include only day, month, and year
#      37 # CORRECTED LINE: Specify the correct format string ('%d-%m-%Y')
# ---> 38 df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'], format='%d-%m-%Y')
#      39 df_fichas_crm['Data/hora inici'] = df_fichas_crm['Data/hora inici'].dt.strftime('%d-%m-%Y')
#      40
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065             result = arg.map(cache_array)
#    1066         else:
# -> 1067             values = convert_listlike(arg._values, format)
#    1068             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431     # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432     if format is not None and format != "mixed":
# --> 433         return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     434
#     435     result, tz_parsed = objects_to_datetime64(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# strptime.pyx in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "01/01/2023 13:50" doesn't match format "%d-%m-%Y", at position 1. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
from os import PRIO_PGRP
# prompt: print 'ContactId' column of df_fichas_crm dataframe

print(df_fichas_crm['ContactId'])
print(df_fichas_crm.columns)
print(df_fichas_crm['Unnamed: 6'])
# Out:
# 0     466.0
# 1     300.0
# 2     300.0
# 3     394.0
# 4     526.0
#       ...
# 63    556.0
# 64    557.0
# 65    300.0
# 66    558.0
# 67    300.0
# Name: ContactId, Length: 68, dtype: float64
# Index(['ID fitxa', 'ID voluntari / Nom voluntari', 'Data/hora inici',
#        'Data/hora final', 'És un xat en blanc?', 'ContactId', 'Unnamed: 6',
#        'Projecte', 'Edat', 'Gènere', 'País de naixement', 'Barri/Districte',
#        'Població', 'Província', 'Comunitat Autònoma',
#        'Trucada de fora d’Espanya', 'Unitat de convivència',
#        'Nivell d’estudis', 'Situació laboral', 'Problemàtica', 'Altres',
#        'Block Ideació suïcida: Carrera suïcida',
#        'Block Ideació suïcida: Ha pensat que seria millor morir-se o ha desitjat estar mort?',
#        'Block Ideació suïcida: Ha volgut fer-se mal?',
#        'Block Ideació suïcida: Ha pensat en el suïcidi?',
#        'Block Ideació suïcida: Ha planejat (planificat) com suïcidar-se?',
#        'Block Ideació suïcida: Ha intentat suicidar-se?',
#        'Block Ideació suïcida: Al llarg de la seva vida: Alguna vegada ha intentat suicidar-se?',
#        'Block Problemes de salut mental: Està diagnosticat?',
#        'Block Problemes de salut mental: Està diagnosticat. Quin',
#        'Block Problemes de salut mental: Pren medicació?',
#        'Block Problemes de salut mental: Pren medicació. Quina',
#        'QUÈ EXPRESSA LA PERSONA QUE XATEJA I OBSERVACIONS', 'ESTAT EMOCIONAL',
#        'Vinculació: Serveis Salut (públics i privats)',
#        'Vinculació: Serveis Socials (públics)',
#        'Vinculació: Teixit Associatiu (entitats privades i públiques)',
#        'Vinculació: No',
#        'Vinculació: No s’ha pogut conèixer aquesta informació',
#        'Vinculació: S’ha ofert informació d’algun recurs',
#        'Vinculació: Si la resposta és “Sí”: Digues quin',
#        'QUÈ S’HA ACONSEGUIT', 'QUÈ S’HA ACONSEGUIT. Altres',
#        'Activació serveis emergències: 061',
#        'Activació serveis emergències: 112 / 116 (Emergències Andorra)',
#        'Activació serveis emergències: 116111 (Infància respon)',
#        'Mantenim el contacte pel xat fins que arriben els serveis d’emergència'],
#       dtype='object')
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
#       ..
# 63   NaN
# 64   NaN
# 65   NaN
# 66   NaN
# 67   NaN
# Name: Unnamed: 6, Length: 68, dtype: float64

# %%
# prompt: cambiar nombre columna ContactId del dataframe de df_tipificaciones  a ContactId1

df_tipificaciones = df_tipificaciones.rename(columns={'ContactId': 'ContactId1'})

# %%
import pandas as pd

df_principal = pd.read_excel('/content/30.01.25 Uic.xlsx', sheet_name='Export')
# subset_df = df_principal[df_principal['OpenchannelInteractionId'] == 1489]

# Cargar la hoja "Export" del archivo 30.01.25_Uic.xlsx
# df_principal = subset_df

# Cargar el archivo de tipificaciones (CSV)
df_tipificaciones = pd.read_excel('/content/20.02.25TipificacionesConversaciones.xlsx')
df_tipificaciones = df_tipificaciones.rename(columns={'ContactId': 'ContactId1'})

# 2️⃣ Cargar el archivo de Fichas CRM (suponiendo que es Excel)
df_fichas_crm = pd.read_excel('/content/20.02.25FichasCrm (2).xlsx')
df_fichas_crm = df_fichas_crm.rename(columns={'ContactId': 'ContactId2'})

# Realizar el LEFT JOIN
df_merged = pd.merge(
    df_principal,
    df_tipificaciones,
    how='left',
    left_on=['OpenchannelInteractionId', 'ContactId'],
    right_on=['id', 'ContactId1']
)

# Verificar el resultado
print(df_merged.head())

# Guardar el resultado en un nuevo archivo CSV (opcional)
df_merged.to_csv('resultado_left_join.csv', index=False)

# Convert 'createdAt' to datetime if it's not already
df_principal['createdAt'] = pd.to_datetime(df_principal['createdAt']) # Remove format to allow pandas to infer

# Format 'createdAt' to include only day, month, and year
df_principal['createdAt'] = df_principal['createdAt'].dt.strftime('%d-%m-%Y')

# Format 'Data/hora inici' to include only day, month, and year
# CORRECTED LINE: Remove format to allow pandas to infer the correct format
df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'])
df_fichas_crm['Data/hora inici'] = df_fichas_crm['Data/hora inici'].dt.strftime('%d-%m-%Y')

# Ensure df_merged1['createdAt'] also has the correct format before the final merge
# Apply the same formatting to df_merged1['createdAt'] and specify format
# using errors='coerce' to handle potential errors during conversion to datetime
df_merged1['createdAt'] = pd.to_datetime(df_merged1['createdAt'], format='%d-%m-%Y', errors='coerce').dt.strftime('%d-%m-%Y')

# Realizar el LEFT JOIN sin renombrar ni crear columnas
df_merged_final = pd.merge(
    df_merged1,
    df_fichas_crm,
    how='left',
    left_on= ['ContactId1','createdAt'],
    right_on=['ContactId2','Data/hora inici']
)


# Verificar el resultado
print(df_merged_final.head())

# Guardar el resultado en un nuevo archivo Excel
df_merged_final.to_excel('resultado_ficha_def.xlsx', index=False)
# Out:
#     id_x                                               body  read  secret  \
# 0  77623                                               Hola     1       0
# 1  77624  Benvingut/da a *Xat de suport emocional per a ...     1       0
# 2  77625                                   Me llamo sakhina     1       0
# 3  77626                                              Hola!     1       0
# 4  77627  Antes de empezar a chatear, es necesario que l...     1       0
#
#   direction              readAt  providerName  providerResponse  \
# 0        in 2023-01-01 00:11:06           NaN               NaN
# 1       out                 NaT           NaN               NaN
# 2        in 2023-01-01 00:11:07           NaN               NaN
# 3       out                 NaT           NaN               NaN
# 4       out                 NaT           NaN               NaN
#
#             createdAt           updatedAt  ...  AttachmentId  integrationId  \
# 0 2023-01-01 00:10:19 2023-01-01 00:11:06  ...           NaN            NaN
# 1 2023-01-01 00:10:19 2023-01-01 00:10:19  ...           NaN            NaN
# 2 2023-01-01 00:10:37 2023-01-01 00:11:07  ...           NaN            NaN
# 3 2023-01-01 00:11:12 2023-01-01 00:11:12  ...           NaN            NaN
# 4 2023-01-01 00:11:33 2023-01-01 00:11:33  ...           NaN            NaN
#
#    parentIntegrationId  sentBy  id_y  closed            closedAt  \
# 0                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 1                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 2                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 3                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 4                  NaN     NaN  1489       1 2023-01-01 00:35:18
#
#       disposition  note  ContactId1
# 0  Conversa atesa   NaN         466
# 1  Conversa atesa   NaN         466
# 2  Conversa atesa   NaN         466
# 3  Conversa atesa   NaN         466
# 4  Conversa atesa   NaN         466
#
# [5 rows x 24 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-181c1988ae49> in <cell line: 0>()
#      47
#      48 # Realizar el LEFT JOIN sin renombrar ni crear columnas
# ---> 49 df_merged_final = pd.merge(
#      50     df_merged1,
#      51     df_fichas_crm,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'ContactId1'

# %%
import pandas as pd

df_principal = pd.read_excel('/content/30.01.25 Uic.xlsx', sheet_name='Export')
# subset_df = df_principal[df_principal['OpenchannelInteractionId'] == 1489]

# Cargar la hoja "Export" del archivo 30.01.25_Uic.xlsx
# df_principal = subset_df

# Cargar el archivo de tipificaciones (CSV)
df_tipificaciones = pd.read_excel('/content/20.02.25TipificacionesConversaciones.xlsx')
df_tipificaciones = df_tipificaciones.rename(columns={'ContactId': 'ContactId1'})

# 2️⃣ Cargar el archivo de Fichas CRM (suponiendo que es Excel)
df_fichas_crm = pd.read_excel('/content/20.02.25FichasCrm (2).xlsx')
df_fichas_crm = df_fichas_crm.rename(columns={'ContactId': 'ContactId2'})

# Realizar el LEFT JOIN
df_merged = pd.merge(
    df_principal,
    df_tipificaciones,
    how='left',
    left_on=['OpenchannelInteractionId', 'ContactId'],
    right_on=['id', 'ContactId1']
)

# Verificar el resultado
print(df_merged.head())

# Guardar el resultado en un nuevo archivo CSV (opcional)
df_merged.to_csv('resultado_left_join.csv', index=False)

# Convert 'createdAt' to datetime if it's not already
df_principal['createdAt'] = pd.to_datetime(df_principal['createdAt']) # Remove format to allow pandas to infer

# Format 'createdAt' to include only day, month, and year
df_principal['createdAt'] = df_principal['createdAt'].dt.strftime('%d-%m-%Y')

# Format 'Data/hora inici' to include only day, month, and year
# CORRECTED LINE: Remove format to allow pandas to infer the correct format
df_fichas_crm['Data/hora inici'] = pd.to_datetime(df_fichas_crm['Data/hora inici'])
df_fichas_crm['Data/hora inici'] = df_fichas_crm['Data/hora inici'].dt.strftime('%d-%m-%Y')

# Ensure df_merged1['createdAt'] also has the correct format before the final merge
# Apply the same formatting to df_merged1['createdAt'] and specify format
# using errors='coerce' to handle potential errors during conversion to datetime
# CHANGED LINE: Rename 'ContactId' to 'ContactId1' to match with df_fichas_crm
df_merged['createdAt'] = pd.to_datetime(df_merged['createdAt'], format='%d-%m-%Y', errors='coerce').dt.strftime('%d-%m-%Y')
df_merged1 = df_merged

# Realizar el LEFT JOIN sin renombrar ni crear columnas
df_merged_final = pd.merge(
    df_merged1,
    df_fichas_crm,
    how='left',
    left_on= ['ContactId1','createdAt'], # Use ContactId1 to match df_tipificaciones's ContactId1
    right_on=['ContactId2','Data/hora inici']
)


# Verificar el resultado
print(df_merged_final.head())

# Guardar el resultado en un nuevo archivo Excel
df_merged_final.to_excel('resultado_ficha_def.xlsx', index=False)
# Out:
#     id_x                                               body  read  secret  \
# 0  77623                                               Hola     1       0
# 1  77624  Benvingut/da a *Xat de suport emocional per a ...     1       0
# 2  77625                                   Me llamo sakhina     1       0
# 3  77626                                              Hola!     1       0
# 4  77627  Antes de empezar a chatear, es necesario que l...     1       0
#
#   direction              readAt  providerName  providerResponse  \
# 0        in 2023-01-01 00:11:06           NaN               NaN
# 1       out                 NaT           NaN               NaN
# 2        in 2023-01-01 00:11:07           NaN               NaN
# 3       out                 NaT           NaN               NaN
# 4       out                 NaT           NaN               NaN
#
#             createdAt           updatedAt  ...  AttachmentId  integrationId  \
# 0 2023-01-01 00:10:19 2023-01-01 00:11:06  ...           NaN            NaN
# 1 2023-01-01 00:10:19 2023-01-01 00:10:19  ...           NaN            NaN
# 2 2023-01-01 00:10:37 2023-01-01 00:11:07  ...           NaN            NaN
# 3 2023-01-01 00:11:12 2023-01-01 00:11:12  ...           NaN            NaN
# 4 2023-01-01 00:11:33 2023-01-01 00:11:33  ...           NaN            NaN
#
#    parentIntegrationId  sentBy  id_y  closed            closedAt  \
# 0                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 1                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 2                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 3                  NaN     NaN  1489       1 2023-01-01 00:35:18
# 4                  NaN     NaN  1489       1 2023-01-01 00:35:18
#
#       disposition  note  ContactId1
# 0  Conversa atesa   NaN         466
# 1  Conversa atesa   NaN         466
# 2  Conversa atesa   NaN         466
# 3  Conversa atesa   NaN         466
# 4  Conversa atesa   NaN         466
#
# [5 rows x 24 columns]
#     id_x                                               body  read  secret  \
# 0  77623                                               Hola     1       0
# 1  77624  Benvingut/da a *Xat de suport emocional per a ...     1       0
# 2  77625                                   Me llamo sakhina     1       0
# 3  77626                                              Hola!     1       0
# 4  77627  Antes de empezar a chatear, es necesario que l...     1       0
#
#   direction              readAt  providerName  providerResponse   createdAt  \
# 0        in 2023-01-01 00:11:06           NaN               NaN  01-01-2023
# 1       out                 NaT           NaN               NaN  01-01-2023
# 2        in 2023-01-01 00:11:07           NaN               NaN  01-01-2023
# 3       out                 NaT           NaN               NaN  01-01-2023
# 4       out                 NaT           NaN               NaN  01-01-2023
#
#             updatedAt  ...  Vinculació: No  \
# 0 2023-01-01 00:11:06  ...              No
# 1 2023-01-01 00:10:19  ...              No
# 2 2023-01-01 00:11:07  ...              No
# 3 2023-01-01 00:11:12  ...              No
# 4 2023-01-01 00:11:33  ...              No
#
#    Vinculació: No s’ha pogut conèixer aquesta informació  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    Vinculació: S’ha ofert informació d’algun recurs  \
# 0                                                No
# 1                                                No
# 2                                                No
# 3                                                No
# 4                                                No
#
#    Vinculació: Si la resposta és “Sí”: Digues quin        QUÈ S’HA ACONSEGUIT  \
# 0                                              NaN  Companyia / socialització
# 1                                              NaN  Companyia / socialització
# 2                                              NaN  Companyia / socialització
# 3                                              NaN  Companyia / socialització
# 4                                              NaN  Companyia / socialització
#
#    QUÈ S’HA ACONSEGUIT. Altres  Activació serveis emergències: 061  \
# 0                          NaN                                  No
# 1                          NaN                                  No
# 2                          NaN                                  No
# 3                          NaN                                  No
# 4                          NaN                                  No
#
#    Activació serveis emergències: 112 / 116 (Emergències Andorra)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    Activació serveis emergències: 116111 (Infància respon)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#    Mantenim el contacte pel xat fins que arriben els serveis d’emergència
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
# [5 rows x 71 columns]
